# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("vingadores.csv", encoding='latin-1')

# %%
print(df.head())
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                 NaN                      Sep-63  1963                   52
# 1                 NaN                      Sep-63  1963                   52
# 2                 NaN                      Sep-63  1963                   52
# 3                 NaN                      Sep-63  1963                   52
# 4                 NaN                      Sep-63  1963                   52
#
#   Honorary  ... Return1 Death2 Return2 Death3 Return3 Death4 Return4 Death5  \
# 0     Full  ...      NO    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 1     Full  ...     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 2     Full  ...     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 3     Full  ...     YES    NaN     NaN    NaN     NaN    NaN     NaN    NaN
# 4     Full  ...     YES    YES      NO    NaN     NaN    NaN     NaN    NaN
#
#   Return5                                              Notes
# 0     NaN  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1     NaN  Dies in Secret Invasion V1:I8. Actually was se...
# 2     NaN  Death: "Later while under the influence of Imm...
# 3     NaN  Dies in Ghosts of the Future arc. However "he ...
# 4     NaN  Dies in Fear Itself brought back because that'...
#
# [5 rows x 21 columns]

# %%
df
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                       Name/Alias  Appearances Current?  Gender  \
# 0      Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                 Janet van Dyne         1165      YES  FEMALE
# 2    Anthony Edward "Tony" Stark         3068      YES    MALE
# 3            Robert Bruce Banner         2089      YES    MALE
# 4                   Thor Odinson         2402      YES    MALE
# ..                           ...          ...      ...     ...
# 168                  Eric Brooks          198      YES    MALE
# 169                Adam Brashear           29      YES    MALE
# 170               Victor Alvarez           45      YES    MALE
# 171                    Ava Ayala           49      YES  FEMALE
# 172                        Kaluu           35      YES    MALE
#
#     Probationary Introl Full/Reserve Avengers Intro  Year  \
# 0                   NaN                      Sep-63  1963
# 1                   NaN                      Sep-63  1963
# 2                   NaN                      Sep-63  1963
# 3                   NaN                      Sep-63  1963
# 4                   NaN                      Sep-63  1963
# ..                  ...                         ...   ...
# 168                 NaN                      13-Nov  2013
# 169                 NaN                      14-Jan  2014
# 170                 NaN                      14-Jan  2014
# 171                 NaN                      14-Jan  2014
# 172                 NaN                      15-Jan  2015
#
#      Years since joining Honorary  ... Return1 Death2 Return2 Death3 Return3  \
# 0                     52     Full  ...      NO    NaN     NaN    NaN     NaN
# 1                     52     Full  ...     YES    NaN     NaN    NaN     NaN
# 2                     52     Full  ...     YES    NaN     NaN    NaN     NaN
# 3                     52     Full  ...     YES    NaN     NaN    NaN     NaN
# 4                     52     Full  ...     YES    YES      NO    NaN     NaN
# ..                   ...      ...  ...     ...    ...     ...    ...     ...
# 168                    2     Full  ...     NaN    NaN     NaN    NaN     NaN
# 169                    1     Full  ...     NaN    NaN     NaN    NaN     NaN
# 170                    1     Full  ...     NaN    NaN     NaN    NaN     NaN
# 171                    1     Full  ...     NaN    NaN     NaN    NaN     NaN
# 172                    0     Full  ...     NaN    NaN     NaN    NaN     NaN
#
#     Death4 Return4 Death5 Return5  \
# 0      NaN     NaN    NaN     NaN
# 1      NaN     NaN    NaN     NaN
# 2      NaN     NaN    NaN     NaN
# 3      NaN     NaN    NaN     NaN
# 4      NaN     NaN    NaN     NaN
# ..     ...     ...    ...     ...
# 168    NaN     NaN    NaN     NaN
# 169    NaN     NaN    NaN     NaN
# 170    NaN     NaN    NaN     NaN
# 171    NaN     NaN    NaN     NaN
# 172    NaN     NaN    NaN     NaN
#
#                                                  Notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
#
# [173 rows x 21 columns]

# %%
print(df.info())

# %% [markdown]
# O código utilizado acima tem como objetivo apresentar as principais informações contidas no nosso DataFrame. Através dele, podemos obter um resumo das colunas, seus tipos de dados e a quantidade de valores não nulos presentes em cada uma.

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# O código acima realiza a substituição de todos os valores nulos (NaN) presentes no DataFrame por zeros. Essa etapa de tratamento de dados é crucial para garantir que a análise subsequente não seja afetada por valores ausentes, permitindo uma interpretação mais precisa dos dados.

# %%
df.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                   0                      Sep-63  1963                   52
# 1                   0                      Sep-63  1963                   52
# 2                   0                      Sep-63  1963                   52
# 3                   0                      Sep-63  1963                   52
# 4                   0                      Sep-63  1963                   52
#
#   Honorary  ... Return1 Death2 Return2 Death3 Return3 Death4 Return4 Death5  \
# 0     Full  ...      NO      0       0      0       0      0       0      0
# 1     Full  ...     YES      0       0      0       0      0       0      0
# 2     Full  ...     YES      0       0      0       0      0       0      0
# 3     Full  ...     YES      0       0      0       0      0       0      0
# 4     Full  ...     YES    YES      NO      0       0      0       0      0
#
#   Return5                                              Notes
# 0       0  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1       0  Dies in Secret Invasion V1:I8. Actually was se...
# 2       0  Death: "Later while under the influence of Imm...
# 3       0  Dies in Ghosts of the Future arc. However "he ...
# 4       0  Dies in Fear Itself brought back because that'...
#
# [5 rows x 21 columns]

# %%
colunas_para_remover = ['Death3',	'Return3',	'Death4',	'Return4',	'Death5',	'Return5']

# %%
df.drop(labels=colunas_para_remover, axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                  URL  \
# 0      http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1  http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2  http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3  http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4   http://marvel.wikia.com/Thor_Odinson_(Earth-616)
#
#                     Name/Alias  Appearances Current?  Gender  \
# 0    Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1               Janet van Dyne         1165      YES  FEMALE
# 2  Anthony Edward "Tony" Stark         3068      YES    MALE
# 3          Robert Bruce Banner         2089      YES    MALE
# 4                 Thor Odinson         2402      YES    MALE
#
#   Probationary Introl Full/Reserve Avengers Intro  Year  Years since joining  \
# 0                   0                      Sep-63  1963                   52
# 1                   0                      Sep-63  1963                   52
# 2                   0                      Sep-63  1963                   52
# 3                   0                      Sep-63  1963                   52
# 4                   0                      Sep-63  1963                   52
#
#   Honorary Death1 Return1 Death2 Return2  \
# 0     Full    YES      NO      0       0
# 1     Full    YES     YES      0       0
# 2     Full    YES     YES      0       0
# 3     Full    YES     YES      0       0
# 4     Full    YES     YES    YES      NO
#
#                                                Notes
# 0  Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1  Dies in Secret Invasion V1:I8. Actually was se...
# 2  Death: "Later while under the influence of Imm...
# 3  Dies in Ghosts of the Future arc. However "he ...
# 4  Dies in Fear Itself brought back because that'...

# %%
df
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                       Name/Alias  Appearances Current?  Gender  \
# 0      Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                 Janet van Dyne         1165      YES  FEMALE
# 2    Anthony Edward "Tony" Stark         3068      YES    MALE
# 3            Robert Bruce Banner         2089      YES    MALE
# 4                   Thor Odinson         2402      YES    MALE
# ..                           ...          ...      ...     ...
# 168                  Eric Brooks          198      YES    MALE
# 169                Adam Brashear           29      YES    MALE
# 170               Victor Alvarez           45      YES    MALE
# 171                    Ava Ayala           49      YES  FEMALE
# 172                        Kaluu           35      YES    MALE
#
#     Probationary Introl Full/Reserve Avengers Intro  Year  \
# 0                     0                      Sep-63  1963
# 1                     0                      Sep-63  1963
# 2                     0                      Sep-63  1963
# 3                     0                      Sep-63  1963
# 4                     0                      Sep-63  1963
# ..                  ...                         ...   ...
# 168                   0                      13-Nov  2013
# 169                   0                      14-Jan  2014
# 170                   0                      14-Jan  2014
# 171                   0                      14-Jan  2014
# 172                   0                      15-Jan  2015
#
#      Years since joining Honorary Death1 Return1 Death2 Return2  \
# 0                     52     Full    YES      NO      0       0
# 1                     52     Full    YES     YES      0       0
# 2                     52     Full    YES     YES      0       0
# 3                     52     Full    YES     YES      0       0
# 4                     52     Full    YES     YES    YES      NO
# ..                   ...      ...    ...     ...    ...     ...
# 168                    2     Full     NO       0      0       0
# 169                    1     Full     NO       0      0       0
# 170                    1     Full     NO       0      0       0
# 171                    1     Full     NO       0      0       0
# 172                    0     Full     NO       0      0       0
#
#                                                  Notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                  0
# 169                                                  0
# 170                                                  0
# 171                                                  0
# 172                                                  0
#
# [173 rows x 15 columns]

# %% [markdown]
# O código acima realiza a remoção de colunas irrelevantes ou sem dados do DataFrame. Essa etapa de limpeza de dados é fundamental para simplificar a análise, eliminando informações desnecessárias que poderiam prejudicar a clareza e o foco nos dados relevantes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
contagem_genero = df['Gender'].value_counts()

# %%
 homens = contagem_genero.get('MALE', 0)
 mulheres = contagem_genero.get('FEMALE', 0)
 contagem_genero
# Out:
# Gender
# MALE      115
# FEMALE     58
# Name: count, dtype: int64

# %%
 generos = ['Homens', 'Mulheres']
 contagens = [homens, mulheres]

# %% [markdown]
# Realizada a contagem de homens e mulheres com dados cadastrados no Daatframe.

# %%
        plt.figure(figsize=(8, 6))  # Tamanho da figura
        plt.bar(generos, contagens, color=['skyblue', 'salmon']) # Cria as barras
        plt.xlabel('Gênero') # Legenda do eixo x
        plt.ylabel('Contagem') # Legenda do eixo y
        plt.title('Distribuição de Gênero') # Título do gráfico
        plt.show() # Exibe o gráfico

# %%
 contagem = df['Current?'].value_counts()

yes_count = contagem.get('YES', 0)
no_count = contagem.get('NO', 0)

# %%
contagem
# Out:
# Current?
# NO     91
# YES    82
# Name: count, dtype: int64

# %% [markdown]
# A análise dos dados revelou que, dos 173 personagens da Marvel presentes no DataFrame, 91 não estão atualmente em histórias da Marvel. Isso indica que há mais personagens fora de circulação do que em atividade no universo Marvel.

# %%
rotulos = ['YES', 'NO']
contagens = [yes_count, no_count]

plt.figure(figsize=(8, 6))
plt.bar(rotulos, contagens, color=['skyblue', 'salmon'])
plt.xlabel('Status')
plt.ylabel('Contagem')
plt.title('Current?')
plt.show()

# %%
df
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                       Name/Alias  Appearances Current?  Gender  \
# 0      Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                 Janet van Dyne         1165      YES  FEMALE
# 2    Anthony Edward "Tony" Stark         3068      YES    MALE
# 3            Robert Bruce Banner         2089      YES    MALE
# 4                   Thor Odinson         2402      YES    MALE
# ..                           ...          ...      ...     ...
# 168                  Eric Brooks          198      YES    MALE
# 169                Adam Brashear           29      YES    MALE
# 170               Victor Alvarez           45      YES    MALE
# 171                    Ava Ayala           49      YES  FEMALE
# 172                        Kaluu           35      YES    MALE
#
#     Probationary Introl Full/Reserve Avengers Intro  Year  \
# 0                     0                      Sep-63  1963
# 1                     0                      Sep-63  1963
# 2                     0                      Sep-63  1963
# 3                     0                      Sep-63  1963
# 4                     0                      Sep-63  1963
# ..                  ...                         ...   ...
# 168                   0                      13-Nov  2013
# 169                   0                      14-Jan  2014
# 170                   0                      14-Jan  2014
# 171                   0                      14-Jan  2014
# 172                   0                      15-Jan  2015
#
#      Years since joining Honorary Death1 Return1 Death2 Return2  \
# 0                     52     Full    YES      NO      0       0
# 1                     52     Full    YES     YES      0       0
# 2                     52     Full    YES     YES      0       0
# 3                     52     Full    YES     YES      0       0
# 4                     52     Full    YES     YES    YES      NO
# ..                   ...      ...    ...     ...    ...     ...
# 168                    2     Full     NO       0      0       0
# 169                    1     Full     NO       0      0       0
# 170                    1     Full     NO       0      0       0
# 171                    1     Full     NO       0      0       0
# 172                    0     Full     NO       0      0       0
#
#                                                  Notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                  0
# 169                                                  0
# 170                                                  0
# 171                                                  0
# 172                                                  0
#
# [173 rows x 15 columns]

# %%
top_20_personagens = df.nlargest(20, 'Appearances')
top_20_personagens
# Out:
#                                                    URL  \
# 73   http://marvel.wikia.com/Peter_Parker_(Earth-616)#
# 6    http://marvel.wikia.com/Steven_Rogers_(Earth-616)
# 92   http://marvel.wikia.com/James_Howlett_(Earth-6...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# 40   http://marvel.wikia.com/Benjamin_Grimm_(Earth-...
# 57   http://marvel.wikia.com/Reed_Richards_(Earth-6...
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 17    http://marvel.wikia.com/Henry_McCoy_(Earth-616)#
# 58    http://marvel.wikia.com/Susan_Storm_(Earth-616)#
# 140  http://marvel.wikia.com/Ororo_Munroe_(Earth-616)#
# 49   http://marvel.wikia.com/Namor_McKenzie_(Earth-...
# 7     http://marvel.wikia.com/Clint_Barton_(Earth-616)
# 141  http://marvel.wikia.com/Matthew_Murdock_(Earth...
# 104  http://marvel.wikia.com/Stephen_Strange_(Earth...
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 9    http://marvel.wikia.com/Wanda_Maximoff_(Earth-...
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 15   http://marvel.wikia.com/Natalia_Romanova_(Eart...
# 13          http://marvel.wikia.com/Vision_(Earth-616)
#
#                          Name/Alias  Appearances Current?  Gender  \
# 73            Peter Benjamin Parker         4333      YES    MALE
# 6                     Steven Rogers         3458      YES    MALE
# 92            James "Logan" Howlett         3130      YES    MALE
# 2       Anthony Edward "Tony" Stark         3068      YES    MALE
# 4                      Thor Odinson         2402      YES    MALE
# 40             Benjamin Jacob Grimm         2305       NO    MALE
# 57                    Reed Richards         2125      YES    MALE
# 3               Robert Bruce Banner         2089      YES    MALE
# 17                   Henry P. McCoy         1886       NO    MALE
# 58       Susan Richards (nee Storm)         1761       NO    MALE
# 140                    Ororo Munroe         1598       NO  FEMALE
# 49                   Namor McKenzie         1561       NO    MALE
# 7            Clinton Francis Barton         1456      YES    MALE
# 141                    Matt Murdock         1375       NO    MALE
# 104  Doctor Stephen Vincent Strange         1324       NO    MALE
# 0         Henry Jonathan "Hank" Pym         1269      YES    MALE
# 9                    Wanda Maximoff         1214      YES  FEMALE
# 1                    Janet van Dyne         1165      YES  FEMALE
# 15       Natalia Alianovna Romanova         1112      YES  FEMALE
# 13             Victor Shade (alias)         1036      YES    MALE
#
#     Probationary Introl Full/Reserve Avengers Intro  Year  \
# 73                    0                      Apr-90  1990
# 6                     0                      Mar-64  1964
# 92                    0                       5-Jun  2005
# 2                     0                      Sep-63  1963
# 4                     0                      Sep-63  1963
# 40                    0                      Jun-86  1986
# 57                    0                      Feb-89  1989
# 3                     0                      Sep-63  1963
# 17               Jul-75                      Sep-76  1976
# 58                    0                      Feb-89  1989
# 140                   0                      12-Jan  2012
# 49                    0                      Dec-85  1985
# 7                     0                      May-65  1965
# 141                   0                      11-Nov  2011
# 104                   0                       7-Feb  2007
# 0                     0                      Sep-63  1963
# 9                     0                      May-65  1965
# 1                     0                      Sep-63  1963
# 15                    0                      May-73  1973
# 13                    0                      Nov-68  1968
#
#      Years since joining Honorary Death1 Return1 Death2 Return2  \
# 73                    25     Full    YES     YES    YES     YES
# 6                     51     Full    YES     YES      0       0
# 92                    10     Full    YES      NO      0       0
# 2                     52     Full    YES     YES      0       0
# 4                     52     Full    YES     YES    YES      NO
# 40                    29     Full    YES     YES      0       0
# 57                    26     Full     NO       0      0       0
# 3                     52     Full    YES     YES      0       0
# 17                    39     Full     NO       0      0       0
# 58                    26     Full     NO       0      0       0
# 140                    3     Full     NO       0      0       0
# 49                    30     Full    YES     YES      0       0
# 7                     50     Full    YES     YES    YES     YES
# 141                    4     Full     NO       0      0       0
# 104                    8     Full     NO       0      0       0
# 0                     52     Full    YES      NO      0       0
# 9                     50     Full    YES     YES      0       0
# 1                     52     Full    YES     YES      0       0
# 15                    42     Full    YES     YES      0       0
# 13                    47     Full    YES     YES      0       0
#
#                                                  Notes
# 73   Since joining the New Avengers: First death Ki...
# 6     Dies at the end of Civil War. Later comes back.
# 92   Died in Death_of_Wolverine_Vol_1_4. Has not ye...
# 2    Death: "Later while under the influence of Imm...
# 4    Dies in Fear Itself brought back because that'...
# 40   Once killed during a battle with Doctor Doom.'...
# 57                                                   0
# 3    Dies in Ghosts of the Future arc. However "he ...
# 17                                                   0
# 58                                                   0
# 140                                                  0
# 49   Namor was presumed killed in the battle with A...
# 7    Dies in exploding Kree ship in Averngers Vol. ...
# 141                                                  0
# 104                                                  0
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 9    Dies in Uncanny_Avengers_Vol_1_14. Later comes...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 15   Killed by The Hand. Later revived with The Sto...
# 13   Dies in Avengers_Vol_1_500. Is eventually rebu...

# %%
print("\nTop 10 personagens com mais aparições:")
for index, row in top_20_personagens.iterrows(): # changed top_10 to top_20 since top_10 isn't defined
    print(f"Nome: {row['Name/Alias']} ") # Added 4 spaces of indentation
# Out:
# Top 10 personagens com mais aparições:
# Nome: Peter Benjamin Parker
# Nome: Steven Rogers
# Nome: James "Logan" Howlett
# Nome: Anthony Edward "Tony" Stark
# Nome: Thor Odinson
# Nome: Benjamin Jacob Grimm
# Nome: Reed Richards
# Nome: Robert Bruce Banner
# Nome: Henry P. McCoy
# Nome: Susan Richards (nee Storm)
# Nome: Ororo Munroe
# Nome: Namor McKenzie
# Nome: Clinton Francis Barton
# Nome: Matt Murdock
# Nome: Doctor Stephen Vincent Strange
# Nome: Henry Jonathan "Hank" Pym
# Nome: Wanda Maximoff
# Nome: Janet van Dyne
# Nome: Natalia Alianovna Romanova
# Nome: Victor Shade (alias)

# %% [markdown]
# Apresentamos aqui os 10 personagens da Marvel com o maior número de aparições em histórias em quadrinhos. A análise revela que esses personagens são também os mais populares e reconhecidos pelo público.

# %%
top_20_personagens_menos_aparicoes = df.nsmallest(20, 'Appearances')
top_20_personagens_menos_aparicoes
# Out:
#                                                    URL           Name/Alias  \
# 39   http://marvel.wikia.com/Moira_Brandon_(Earth-6...        Moira Brandon
# 125  http://marvel.wikia.com/Fiona_(Inhuman)_(Earth...                Fiona
# 68   http://marvel.wikia.com/Doug_Taggert_(Earth-616)#         Doug Taggert
# 65   http://marvel.wikia.com/Gene_Lorrene_(Earth-616)#         Gene Lorrene
# 117  http://marvel.wikia.com/Dennis_Sykes_(Earth-616)#         Dennis Sykes
# 67     http://marvel.wikia.com/Monkey_Joe_(Earth-616)#                    0
# 165  http://marvel.wikia.com/Monica_Chang_(Earth-616)#         Monica Chang
# 167        http://marvel.wikia.com/Alexis_(Earth-616)#               Alexis
# 166  http://marvel.wikia.com/Doombot_(Avenger)_(Ear...                    0
# 69      http://marvel.wikia.com/Tippy-Toe_(Earth-616)#                    0
# 83   http://marvel.wikia.com/Giuletta_Nefaria_(Masq...  "Giulietta Nefaria"
# 138  http://marvel.wikia.com/Takashi_Matsuya_(Earth...         Taki Matsuya
# 61     http://marvel.wikia.com/Dinah_Soar_(Earth-616)#                    0
# 127        http://marvel.wikia.com/Hollow_(Earth-616)#               Yvette
# 158  http://marvel.wikia.com/America_Chavez_(Earth-...       America Chavez
# 95   http://marvel.wikia.com/Nathaniel_Richards_(Ir...   Nathaniel Richards
# 89   http://marvel.wikia.com/Kelsey_Leigh_(Earth-616)#   Kelsey Leigh Shorr
# 153     http://marvel.wikia.com/Ex_Nihilo_(Earth-616)#                    0
# 154  http://marvel.wikia.com/Abyss_(Ex_Nihilo%27s)_...                    0
# 123  http://marvel.wikia.com/Emery_Schaub_(Earth-616)#         Emery Schaub
#
#      Appearances Current?  Gender Probationary Introl  \
# 39             2       NO  FEMALE                   0
# 125            2      YES  FEMALE                   0
# 68             3       NO    MALE                   0
# 65             4       NO    MALE                   0
# 117            6       NO    MALE                   0
# 67             7       NO    MALE                   0
# 165           12      YES  FEMALE                   0
# 167           13      YES  FEMALE                   0
# 166           14      YES    MALE                   0
# 69            16       NO  FEMALE                   0
# 83            18       NO  FEMALE                   0
# 138           18      YES    MALE                   0
# 61            22       NO  FEMALE                   0
# 127           22      YES  FEMALE                   0
# 158           22      YES  FEMALE                   0
# 95            23       NO    MALE                   0
# 89            24       NO  FEMALE                   0
# 153           24      YES    MALE                   0
# 154           25      YES  FEMALE                   0
# 123           26      YES    MALE                   0
#
#     Full/Reserve Avengers Intro  Year  Years since joining  Honorary Death1  \
# 39                       Nov-93  1993                   22  Honorary    YES
# 125                           0  1900                  115   Academy     NO
# 68                        5-May  2005                   10      Full    YES
# 65                        5-Apr  2005                   10      Full     NO
# 117                      10-Sep  2010                    5      Full    YES
# 67                        5-May  2005                   10      Full    YES
# 165                      13-Sep  2013                    2      Full     NO
# 167                      13-Nov  2013                    2      Full     NO
# 166                      13-Sep  2013                    2      Full     NO
# 69                        5-Jul  2005                   10      Full     NO
# 83                       Apr-96  1996                   19  Honorary    YES
# 138                           0  1900                  115   Academy     NO
# 61                       Jul-89  1989                   26      Full    YES
# 127                           0  1900                  115   Academy     NO
# 158                      13-Jul  2013                    2      Full     NO
# 95                        5-Apr  2005                   10      Full     NO
# 89                        4-Jun  2004                   11      Full     NO
# 153                      13-Oct  2013                    2      Full    YES
# 154                      13-Oct  2013                    2      Full    YES
# 123                           0  1900                  115   Academy     NO
#
#     Return1 Death2 Return2                                              Notes
# 39       NO      0       0  Died in her second appearance earns honorary A...
# 125       0      0       0                                                  0
# 68       NO      0       0                         Accidently killed by Zaran
# 65        0      0       0                                                  0
# 117      NO      0       0  Died in Heroic_Age:_One_Month_to_Live_Vol_1_5 ...
# 67       NO      0       0                              Killed by Leather Boy
# 165       0      0       0                                                  0
# 167       0      0       0                                                  0
# 166       0      0       0                                                  0
# 69        0      0       0                                                  0
# 83       NO      0       0  Whitney killed was a clone possibly this incar...
# 138       0      0       0                                                  0
# 61       NO      0       0  Died in Great_Lakes_Avengers_Vol_1_1. Has not ...
# 127       0      0       0                                                  0
# 158       0      0       0                                                  0
# 95        0      0       0   NA is actually Kang but let's just not go there.
# 89        0      0       0                                                  0
# 153      NO      0       0                      Died in New_Avengers_Vol_3_32
# 154      NO      0       0                      Died in New_Avengers_Vol_3_32
# 123       0      0       0                                                  0

# %%
print("\nTop 10 personagens com menoos aparições:")
for index, row in top_20_personagens_menos_aparicoes.iterrows(): # changed top_10 to top_20 since top_10 isn't defined
    print(f"Nome: {row['Name/Alias']} ") # Added 4 spaces of indentation
# Out:
# Top 10 personagens com menoos aparições:
# Nome: Moira Brandon
# Nome: Fiona
# Nome: Doug Taggert
# Nome: Gene Lorrene
# Nome: Dennis Sykes
# Nome: 0
# Nome: Monica Chang
# Nome: Alexis
# Nome: 0
# Nome: 0
# Nome: "Giulietta Nefaria"
# Nome: Taki Matsuya
# Nome: 0
# Nome: Yvette
# Nome: America Chavez
# Nome: Nathaniel Richards
# Nome: Kelsey Leigh Shorr
# Nome: 0
# Nome: 0
# Nome: Emery Schaub

# %% [markdown]
# Observamos a presença de personagens com a coluna 'Nome' preenchida com o valor 0, indicando a ausência de um nome válido. Para assegurar a precisão da análise, removeremos esses personagens. Após a limpeza, identificaremos novamente os 10 personagens com menos aparições no DataFrame resultante.

# %%
def remover_linhas_nome_zero_inplace(df):
    """
    Remove linhas onde 'Name/Alias' é '0' usando drop() e inplace=True.
    """
    indices_para_remover = df[df['Name/Alias'] == '0'].index
    df.drop(indices_para_remover, inplace=True)

# Supondo que 'df' seja o seu DataFrame original
# ... (seu código para carregar ou criar o DataFrame)

# Removendo as linhas (modifica o DataFrame original)
remover_linhas_nome_zero_inplace(df)

# %%
df
# Out:
#                                                    URL  \
# 0        http://marvel.wikia.com/Henry_Pym_(Earth-616)
# 1    http://marvel.wikia.com/Janet_van_Dyne_(Earth-...
# 2    http://marvel.wikia.com/Anthony_Stark_(Earth-616)
# 3    http://marvel.wikia.com/Robert_Bruce_Banner_(E...
# 4     http://marvel.wikia.com/Thor_Odinson_(Earth-616)
# ..                                                 ...
# 168   http://marvel.wikia.com/Eric_Brooks_(Earth-616)#
# 169  http://marvel.wikia.com/Adam_Brashear_(Earth-6...
# 170  http://marvel.wikia.com/Victor_Alvarez_(Earth-...
# 171     http://marvel.wikia.com/Ava_Ayala_(Earth-616)#
# 172         http://marvel.wikia.com/Kaluu_(Earth-616)#
#
#                       Name/Alias  Appearances Current?  Gender  \
# 0      Henry Jonathan "Hank" Pym         1269      YES    MALE
# 1                 Janet van Dyne         1165      YES  FEMALE
# 2    Anthony Edward "Tony" Stark         3068      YES    MALE
# 3            Robert Bruce Banner         2089      YES    MALE
# 4                   Thor Odinson         2402      YES    MALE
# ..                           ...          ...      ...     ...
# 168                  Eric Brooks          198      YES    MALE
# 169                Adam Brashear           29      YES    MALE
# 170               Victor Alvarez           45      YES    MALE
# 171                    Ava Ayala           49      YES  FEMALE
# 172                        Kaluu           35      YES    MALE
#
#     Probationary Introl Full/Reserve Avengers Intro  Year  \
# 0                     0                      Sep-63  1963
# 1                     0                      Sep-63  1963
# 2                     0                      Sep-63  1963
# 3                     0                      Sep-63  1963
# 4                     0                      Sep-63  1963
# ..                  ...                         ...   ...
# 168                   0                      13-Nov  2013
# 169                   0                      14-Jan  2014
# 170                   0                      14-Jan  2014
# 171                   0                      14-Jan  2014
# 172                   0                      15-Jan  2015
#
#      Years since joining Honorary Death1 Return1 Death2 Return2  \
# 0                     52     Full    YES      NO      0       0
# 1                     52     Full    YES     YES      0       0
# 2                     52     Full    YES     YES      0       0
# 3                     52     Full    YES     YES      0       0
# 4                     52     Full    YES     YES    YES      NO
# ..                   ...      ...    ...     ...    ...     ...
# 168                    2     Full     NO       0      0       0
# 169                    1     Full     NO       0      0       0
# 170                    1     Full     NO       0      0       0
# 171                    1     Full     NO       0      0       0
# 172                    0     Full     NO       0      0       0
#
#                                                  Notes
# 0    Merged with Ultron in Rage of Ultron Vol. 1. A...
# 1    Dies in Secret Invasion V1:I8. Actually was se...
# 2    Death: "Later while under the influence of Imm...
# 3    Dies in Ghosts of the Future arc. However "he ...
# 4    Dies in Fear Itself brought back because that'...
# ..                                                 ...
# 168                                                  0
# 169                                                  0
# 170                                                  0
# 171                                                  0
# 172                                                  0
#
# [173 rows x 15 columns]

# %%
def  top_10_menos_aparicoes(df, coluna_aparicoes='Appearances', coluna_nome='Name/Alias'):
    """
    Mostra os 10 personagens com menos aparições em um DataFrame.
    """
    df_ordenado = df.sort_values(by=coluna_aparicoes, ascending=True)
def  top_10_menos_aparicoes(df, coluna_aparicoes='Appearances', coluna_nome='Name/Alias'):
    """
    Mostra os 10 personagens com menos aparições em um DataFrame.
    """
    df_ordenado = df.sort_values(by=coluna_aparicoes, ascending=True)
    top_10 = df_ordenado.head(10)
    print("\nTop 10 personagens com menos aparições (após remoção de nomes ausentes):")
    for index, row in top_10.iterrows():
        print(f"Nome: {row[coluna_nome]}")

top_10_menos_aparicoes(df)
# Out:
# Top 10 personagens com menos aparições (após remoção de nomes ausentes):
# Nome: Moira Brandon
# Nome: Fiona
# Nome: Doug Taggert
# Nome: Gene Lorrene
# Nome: Dennis Sykes
# Nome: 0
# Nome: Monica Chang
# Nome: Alexis
# Nome: 0
# Nome: 0
